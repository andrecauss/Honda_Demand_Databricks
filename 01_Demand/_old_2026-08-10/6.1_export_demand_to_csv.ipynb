# %%
# ============================================================================
# MODO TESTE
# ============================================================================

TEST_MODE = True

TEST_TABLE = "refined_demand_fechada"

# %%
# André Causs - 07/08/2026 : Exporta uma única tabela para CSV

CATALOG = "parts_hdbk_sandbox"
SCHEMA = "pr_demand"
TABLE = "refined_demand_fechada"

OUTPUT_PATH = (
    f"/Volumes/{CATALOG}/{SCHEMA}/export_file/{TABLE}"
)

df = spark.table(
    f"{CATALOG}.{SCHEMA}.{TABLE}"
)

(
    df.coalesce(1)
      .write
      .mode("overwrite")
      .option("header", "true")
      .csv(OUTPUT_PATH)
)

print(f"CSV gerado em: {OUTPUT_PATH}")

# %%
for table_name in tables:

    full_table_name = f"{CATALOG}.{SCHEMA}.{table_name}"

    print(f"Exportando {full_table_name}")

    df = spark.table(full_table_name)

    ...
